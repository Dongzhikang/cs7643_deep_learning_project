# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Final_Project/team_implementation'
# Verify the contents of the current folder
# Out:
# /content/drive/MyDrive/Final_Project/team_implementation

# %%
#!pip install -r requirements.txt

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("You are using device: %s" % device)
# Out:
# You are using device: cuda

# %%
# !python main_supcon.py --batch_size 256 --num_workers 2 --epochs 40 --learning_rate 0.05 --model 'resnet50' --dataset 'cifar10' --temp 0.15
# Out:
# Files already downloaded and verified
# Train: [1][10/196]	BT 0.293 (0.778)	DT 0.217 (0.091)	loss 13.364 (13.370)
# Train: [1][20/196]	BT 0.332 (0.515)	DT 0.258 (0.121)	loss 13.362 (13.366)
# Train: [1][30/196]	BT 0.312 (0.427)	DT 0.237 (0.139)	loss 13.360 (13.365)
# Train: [1][40/196]	BT 0.277 (0.383)	DT 0.203 (0.149)	loss 13.357 (13.363)
# Train: [1][50/196]	BT 0.185 (0.357)	DT 0.111 (0.154)	loss 13.330 (13.359)
# Train: [1][60/196]	BT 0.315 (0.341)	DT 0.241 (0.160)	loss 13.259 (13.345)
# Train: [1][70/196]	BT 0.321 (0.329)	DT 0.246 (0.163)	loss 13.167 (13.329)
# Train: [1][80/196]	BT 0.308 (0.319)	DT 0.234 (0.164)	loss 13.244 (13.312)
# Train: [1][90/196]	BT 0.280 (0.311)	DT 0.206 (0.166)	loss 13.154 (13.299)
# Train: [1][100/196]	BT 0.284 (0.305)	DT 0.210 (0.167)	loss 13.029 (13.284)
# Train: [1][110/196]	BT 0.332 (0.301)	DT 0.255 (0.168)	loss 13.120 (13.272)
# Train: [1][120/196]	BT 0.336 (0.297)	DT 0.262 (0.168)	loss 13.135 (13.262)
# ...

# %%
# !python main_linear_w_output.py --batch_size 256 --num_workers 2 --epochs 40 --learning_rate 0.05 --model 'resnet50' --dataset 'cifar10' \
                       --ckpt './save/SupCon/cifar10_models/SupCon_cifar10_resnet50_lr_0.05_decay_0.0001_bsz_256_temp_0.15_trial_0/last.pth'
# Out:
# Files already downloaded and verified
# Train: [1][10/196]	BT 0.091 (0.337)	DT 0.061 (0.050)	loss 0.705 (0.977)	Acc@1 86.719 (74.141)
# Train: [1][20/196]	BT 0.095 (0.200)	DT 0.063 (0.041)	loss 0.887 (1.026)	Acc@1 89.062 (80.488)
# Train: [1][30/196]	BT 0.099 (0.155)	DT 0.069 (0.039)	loss 1.119 (1.011)	Acc@1 85.938 (83.203)
# Train: [1][40/196]	BT 0.095 (0.132)	DT 0.065 (0.037)	loss 0.953 (0.957)	Acc@1 86.328 (84.590)
# Train: [1][50/196]	BT 0.098 (0.119)	DT 0.067 (0.037)	loss 0.817 (0.923)	Acc@1 88.672 (85.398)
# Train: [1][60/196]	BT 0.094 (0.109)	DT 0.064 (0.036)	loss 0.707 (0.891)	Acc@1 88.281 (85.762)
# Train: [1][70/196]	BT 0.106 (0.103)	DT 0.076 (0.036)	loss 0.536 (0.861)	Acc@1 87.109 (85.904)
# Train: [1][80/196]	BT 0.098 (0.098)	DT 0.068 (0.036)	loss 0.368 (0.818)	Acc@1 88.672 (86.079)
# Train: [1][90/196]	BT 0.095 (0.094)	DT 0.065 (0.035)	loss 0.563 (0.789)	Acc@1 87.109 (86.276)
# ...
